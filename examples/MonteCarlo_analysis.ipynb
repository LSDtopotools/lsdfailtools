# %% [markdown]
# # How to do a Monte-Carlo simulation of failure times with lsdfailtools
#
# This notebook shows how to set up the range of parameters and run a given number of simulation on parallel cores
#
# ## First let's import the model and the rainfall data

# %%
# Importing the model
import lsdfailtools.iverson2000 as iverson
# I'll need that to process the outputs
import pandas as pd
import numpy as np

# rainfall data
df = pd.read_csv("preprocessed_data.csv")

# Setting the depth resolution vector
depths = np.arange(0.2,3.1,0.1)

# %% [markdown]
# ## Now let's set up the parameter ranges
#
# The function call is a bit chunky but simply add the different minimum and maximum values for eahc parameter and the code will randomly sample values within it.
#
# Note that `D_0`and `K_sat_min` are sampled in log space and the other are uniform. The depth resolution needs to be the same for each siumulation.

# %%
MCrun = iverson.MonteCarlo_Iverson( alpha_min = 0.1, D_0_min = 1e-6,K_sat_min = 1e-8, d_min = 0.5,Iz_over_K_steady_min = 0.1,
      friction_angle_min = 0.2, cohesion_min = 5000, weight_of_water_min = 9800, 
      weight_of_soil_min = 15000, alpha_max = 0.8, D_0_max = 1e-4,K_sat_max = 1e-6, d_max = 3,Iz_over_K_steady_max = 0.8,
      friction_angle_max = 0.5, cohesion_max = 20000, weight_of_water_max = 9801, 
      weight_of_soil_max = 25000, depths = depths)

# %% [markdown]
# ## Now let's run the simulations
#
# The simulation are run for a given set of precipitation record. The simulation can take a lot of time, it saves the output into a csv every 20 simulations if you need to look at intermediate resulsts.

# %%
MCrun.run_MC_failure_test(df["duration_s"].values, df["intensity_mm_sec"].values,
                          n_process = 2, output_name = "test_MC.csv", n_iterations = 100, replace = True)
# Out:
# m is  [Empty DataFrame
# Columns: [alpha, D_0, K_sat, d, Iz_over_K_steady, friction_angle, cohesion, weight_of_water, weight_of_soil, time_of_failure]
# Index: [], 'test_MC.csv']
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.338835  0.000013  7.367725e-08  0.661763          0.341909
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.388999  5004.113259      9800.010386    15788.498986
#
#    time_of_failure
# 0        7602278.5
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.388451  0.000002  6.968569e-07  2.977544          0.623231
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.226972  18480.16953      9800.532306    16341.865111
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.726721  0.000002  7.209338e-07  1.559036          0.168466
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.430196  6727.950179      9800.996675    18297.190479
#
#    time_of_failure
# 0              0.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.137422  0.000041  4.865128e-08  2.425356          0.295615
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.391725  7447.110891      9800.977367    18592.239733
#
#    time_of_failure
# 0       13296723.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.786377  0.000063  7.180985e-07  2.281022          0.397641
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.219268  14314.871599      9800.630276    22336.657546
#
#    time_of_failure
# 0              0.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.617488  0.000008  3.772601e-07  2.964294          0.759469
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.243417  19562.581523      9800.881707    18464.513206
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.397236  0.000001  1.618683e-07  2.135835          0.530299
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.329625  6632.914427      9800.170833    16751.583258
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.613351  0.000001  1.088672e-08  2.050823          0.353892
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.463843  12736.845642      9800.877603    21768.713949
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.687867  0.000011  6.301375e-08  1.934815          0.413379
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.241679  5886.332808      9800.816032    23531.635955
#
#    time_of_failure
# 0              0.0
# m is       alpha      D_0         K_sat         d  Iz_over_K_steady  friction_angle  \
# 0  0.19074  0.00004  1.505841e-07  0.683916          0.491882        0.298805
#
#        cohesion  weight_of_water  weight_of_soil  time_of_failure
# 0  18097.805091      9800.126176    16176.862913            -9999
# m is       alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat        d  Iz_over_K_steady  \
# 0  0.601575  0.000002  4.814271e-08  2.74576          0.229798
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.298012  12517.331491      9800.905191    21628.743528
#
#    time_of_failure
# 0              0.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.598258  0.000009  1.109945e-08  1.511185          0.160265
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.254788  12387.526177      9800.528982     21723.79216
#
#    time_of_failure
# 0              0.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.688071  0.000058  6.257128e-07  1.839919          0.568836
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.302377  17496.408069      9800.094936    20865.711345
#
#    time_of_failure
# 0              0.0
# m is       alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.13606  0.000091  1.381641e-07  1.852348          0.770785
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.459603  12289.998314      9800.284688    22920.932978
#
#    time_of_failure
# 0        7404279.5
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.363844  0.000001  6.025321e-07  2.940251          0.641994
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.390345  10070.092814      9800.135375    23659.758322
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.229389  0.000002  1.344525e-08  2.701865          0.458124
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.468713  17028.357699       9800.45526    15811.197199
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.330088  0.000052  3.590980e-07  0.532156          0.470527
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0         0.37281  14751.063701       9800.65118    19430.168359
#
#    time_of_failure
# 0       13303921.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.673058  0.000063  6.581458e-08  2.964936          0.407555
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.239555  15763.804521      9800.667353    20131.602393
#
#    time_of_failure
# 0              0.0
# m is        alpha       D_0         K_sat        d  Iz_over_K_steady  \
# 0  0.700895  0.000014  9.689011e-08  0.98704          0.291252
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.233736  8201.306948       9800.55738    18394.265731
#
#    time_of_failure
# 0              0.0
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.259359  0.000006  3.474524e-07  1.527134          0.205725
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.441909  11996.186886      9800.860412    23879.872772
#
#    time_of_failure
# 0            -9999
# m is       alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.66732  0.000021  1.720040e-08  2.960593          0.421799
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.436188  15212.652399      9800.907344    24603.931693
#
#    time_of_failure
# 0      1255503.625
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.464937  0.000071  8.228005e-07  1.210083           0.26465
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.401042  15289.085832      9800.520121    18561.257668
#
#    time_of_failure
# 0        7602278.5
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.381153  0.000004  8.950069e-07  2.192754          0.419621
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0         0.24615  14969.365253      9800.852693    18031.182686
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.598488  0.000003  1.726908e-07  2.457074          0.151563
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.416317  14815.192031      9800.351451    16161.653935
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.345169  0.000006  2.294158e-07  1.352682           0.46934
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0         0.29538  15044.452577      9800.162045     17194.42718
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat        d  Iz_over_K_steady  \
# 0  0.186009  0.000002  2.851363e-08  0.89622          0.291255
#
#    friction_angle    cohesion  weight_of_water  weight_of_soil  \
# 0        0.458459  5623.74381      9800.762506    19541.334898
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.426185  0.000002  1.124161e-08  1.327105          0.545307
#
#    friction_angle      cohesion  weight_of_water  weight_of_soil  \
# 0        0.398626  18369.798946      9800.921708    17461.211046
#
#    time_of_failure
# 0            -9999
# m is        alpha       D_0         K_sat         d  Iz_over_K_steady  \
# 0  0.289485  0.000059  7.996040e-07  1.932306          0.391676
#
#    friction_angle     cohesion  weight_of_water  weight_of_soil  \
# 0        0.410662  5637.153112      9800.543701    21514.086628
#
#    time_of_failure
# 0        7400685.5
# m is  kill

# %% [markdown]
# ## Now Checking the output
#
# Let's load the csv filecontaining the result. The column "time_of_failure" contains the ... time of failure. -9999 Means no failure and 0. means failure from scratch.

# %%
res = pd.read_csv("test_MC.csv")
res["time_of_failure"])
# Out:
#   File "<ipython-input-2-c537db5ffb25>", line 2
#     res["time_of_failure"])
#                           ^
# SyntaxError: invalid syntax
